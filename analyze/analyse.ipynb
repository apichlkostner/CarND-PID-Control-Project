# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('../build/meas_0.216005_0.108957_0.128885.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
df.head()
# Out:
#     -     cte   control   angle  velocity  throttle
# 0 NaN  0.7599 -0.164142  0.4363    1.2015       1.0
# 1 NaN  0.7599 -0.170016  0.4363    1.6863       1.0
# 2 NaN  0.7597 -0.175906 -3.6672    1.0266       1.0
# 3 NaN  0.7589 -0.180481 -3.8141    0.7413       1.0
# 4 NaN  0.7576 -0.184610 -3.9613    1.0706       1.0

# %%
plt.figure(figsize=(20,10))
plt.plot(df['cte'], 'r', df['control'], 'g')

# %%
df2 = pd.read_csv('../build/meas_0.150000_0.108957_0.128885.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
plt.figure(figsize=(20,10))
plt.plot(df2['cte'], 'r', df2['control'], 'g')

# %%
df2 = pd.read_csv('../build/meas_0.100000_0.100000_0.120000.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
plt.figure(figsize=(20,10))
plt.plot(df2['cte'], 'r', df2['control'], 'g')

# %%
df2 = pd.read_csv('../build/meas_0.100000_0.100000_0.050000.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
plt.figure(figsize=(20,10))
plt.plot(df2['cte'], 'r', df2['control'], 'g')

# %%
df2 = pd.read_csv('../build/meas_0.100000_0.050000_0.050000.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
plt.figure(figsize=(20,10))
plt.plot(df2['cte'], 'r', df2['control'], 'g')

# %%
df2 = pd.read_csv('../build/meas_0.100000_0.100000_0.050000.csv',
                 names=['-', 'cte', 'control', 'angle', 'velocity', 'throttle'],
                skiprows=10)
plt.figure(figsize=(20,10))
weight = 0.1
plt.plot(weight*df2['cte']*df2['cte'], 'r', (1.0-weight)*df2['control']*df2['control'], 'g')
